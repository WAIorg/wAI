# %% [markdown]
# Variables

# %%
# changing parameters
volume = 72 # in letres 
sex = "male"

# volume = 67
# sex= "female"

# average density for humans 
density = 985 # kg/m^3

# %% [markdown]
# Weight Calculations

# %%
sex_num = 1 if sex == "male" else 2
weight = 4.572 - (1.61*sex_num) + 0.9728 * volume
print("weight (kg): ", weight)
# Out:
# weight:  73.0036

# %%
# https://apps.dtic.mil/sti/citations/AD0657316 - no female 
if sex == "male":
    weight = (volume + 4.937) / 1.015
    print("weight (kg): ", weight)
# Out:
# weight:  75.80000000000001

# %%
# general equation 
weight = volume * density
print("weight (kg): ", weight)
# Out:
# weight:  70920
